# %% [markdown]
# ## Pyplot Tutorial

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# In this plot, the reason that the x-axis ranges form 0-3 nad the y-axis 1-4 is because matplotlib assumes the plot() command is a sequence of y values, then the program auto generates the x values for you, and since python ranges start with 0, it by default did 0-3.

# %% [markdown]
# To quickly Plot a x vs y graph do:

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %% [markdown]
# You can change the way in which things are plotted by specifying what should happen in the string format.  by default, the string format is **b-** which is a solid blue line. To do something like red circles, you could use:

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# The following sampels plotting several lines with different format styles in one command using arrays.

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2,'bs', t, t**3, 'g^' )
plt.show()

# %% [markdown]
# ### Plotting with keyword strings
# Matplotlib allows you to provide certain objects with the *data* keyword arguement.  Once provided you can use them in your strings

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [markdown]
# ### Plotting with categorical variables
# You are able to pass categorical variables directly to plotting functions:

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(1, figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ### Controlling line properties
# you can set: linewidth, dash style, antialiased, etc;

# %% [markdown]
# Using keyword args:

# %%
plt.plot(x, y, linewidth=2.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fc149bd736ee> in <module>
# ----> 1 plt.plot(x, y, linewidth=2.0)
#
# NameError: name 'x' is not defined

# %% [markdown]
# Using the setter methods of a *Line2D* instance.

# %%
line, = plt.plot(x, y, '-')
line.set_antialaliased(False) # turn off antialising

# %% [markdown]
# Using the *setup()* Command

# %%
lines = plt.plot(x1, y1, x2, y2)
# use keyword args
plt.setp(lines, color='r', linewidth=2.0)
# or MATLAB style string value pairs
plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9ef1f096dff6> in <module>
# ----> 1 lines = plt.plot(x1, y1, x2, y2)
#       2 # use keyword args
#       3 plt.setp(lines, color='r', linewidth=2.0)
#       4 # or MATLAB style string value pairs
#       5 plt.setp(lines, 'color', 'r', 'linewidth', 2.0)
#
# NameError: name 'x1' is not defined

# %% [markdown]
# ### Here are the available *Line2D* Properties
# ![Screen%20Shot%202019-02-08%20at%203.25.17%20PM.png](attachment:Screen%20Shot%202019-02-08%20at%203.25.17%20PM.png)

# %% [markdown]
# #### To get a list of settable line properties, call the setp() function with a line or lines as arugment

# %%
lines = plt.plot([1, 2, 3])

# %%
plt.setp(lines)
alpha: float
animated: [True | False]
...snip
# Out:
#   File "<ipython-input-14-883c5b2295c9>", line 4
#     ...snip
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Working with multiple figures and axes
# The function *gca()* returns the currents axes, and *gcf()* returns the current figure.

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# The *figure()* command is optional here bc figure(1) will be created by default.  The *subplot() command specifies \bf numrows, numcols, and plot_number.

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# /Users/masond/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# Text(0.5, 1.0, 'Easy as 1, 2, 3')

# %% [markdown]
# The memory required for a figure is not completely released until the figure is explicitly closed with *close()*

# %% [markdown]
# ### Working with text
# *text()* command can be used to add text in arbitary location
# *xlabel(), ylabel(), title()* can be used to add text in indicated locations

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(1000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probablilty')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
t = plt.xlabel('my data', fontsize=14, color='red')

# %% [markdown]
# ### Mathemetical expressions in text

# %%
plt.title(r'$\sigma_i=15$')

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2,1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2, 2)
plt.show()

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()
